# %%
import pandas as pd

tuning_result = pd.read_csv("/Data1/hmd2/notebooks_th/Hmd_github/Tuning_results/tuning_results.csv", index_col= [0])
tuning_result.sort_values(by = ["Test_WMA_stu" , "Test_WMA_tch"], ascending= False).head()
# Out:
#     epx_num      lr  pos_weight  mix_up_bool  const_max  optim_threshold_stu  \
# 5         6  0.0010         4.0         True        1.0                 0.55
# 6         7  0.0010         4.0        False        2.0                 0.69
# 19       20  0.0005         4.0         True        2.0                 0.76
# 18       19  0.0005         4.0        False        2.0                 0.59
# 15       16  0.0005         3.0         True        2.0                 0.54
#
#     optim_threshold_tch  Val_WMA_stu  Val_WMA_tch  Test_WMA_stu  Test_WMA_tch
# 5                   0.0     0.513317          1.0      0.795148      0.719677
# 6                   0.0     0.520581          1.0      0.787062      0.757412
# 19                  0.0     0.498789          1.0      0.787062      0.690027
# 18                  0.0     0.547215          1.0      0.776280      0.722372
# 15                  0.0     0.506053          1.0      0.768194      0.722372

# %%
import pandas as pd

tuning_result = pd.read_csv("/Data1/hmd2/notebooks_th/Hmd_github/Tuning_results/tuning_results_2.csv", index_col= [0])
tuning_result.sort_values(by = ["Test_WMA_stu" , "Test_WMA_tch"], ascending= False).head()
# Out:
#     epx_num      lr  pos_weight  mix_up_bool  const_max  optim_threshold_stu  \
# 5         6  0.0010         4.0         True        1.0                 0.43
# 2         3  0.0010         3.0        False        2.0                 0.42
# 18       19  0.0005         4.0        False        2.0                 0.24
# 8         9  0.0010         5.0        False        1.0                 1.00
# 0         1  0.0010         3.0        False        1.0                 0.44
#
#     optim_threshold_tch  Val_WMA_stu  Val_WMA_tch  Test_WMA_stu  Test_WMA_tch
# 5                   0.0     0.513317     1.000000      0.792453      0.730458
# 2                   0.0     0.523002     0.681818      0.778976      0.762803
# 18                  0.0     0.535109     1.000000      0.770889      0.752022
# 8                   0.0     0.520581     1.000000      0.765499      0.719677
# 0                   0.0     0.501211     1.000000      0.760108      0.719677
